# %%
import h5py
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
dataset_path = "../data_collection/"

def loadread_dataset(filename):
    return h5py.File(filename, 'r', swmr=True, libver = 'latest')

def loadedit_dataset(filename):
    return h5py.File(filename, 'r+')

# %%
filename_list = []
for file in os.listdir(dataset_path):
    if file.endswith(".h5"): # and len(filename_list) < 20:
        filename_list.append(dataset_path + file)

print(len(filename_list))
for filename in filename_list:
    print(filename)
    f = loadedit_dataset(filename)
#     print('insertion' in f.keys())
    hole_type = np.array(f['hole_type'])
    peg_type = np.array(f['peg_type'])
        
    height = np.array(f['proprio'])[:,2]
    width = np.array(f['proprio'])[:,0]
    length = np.array(f['proprio'])[:,1]
    insertion = np.zeros(height.shape[0])
    
#     for i in range(height.shape[0]):
#         h = height[i]
#         w = width[i]
#         l = length[i]

#         if h < -0.002 and abs(w) < 0.0015\
#         and abs(w) < 0.0015 and hole_type.argmax() == peg_type.argmax():
#             insertion[i] = 1.0
#         else:
#             insertion[i] = 0.0

#     if 'insertion' not in f.keys():
#         print(filename)
#         f.create_dataset("insertion", data = insertion)
        
#     f.close()
# plt.plot(, dist_list)
# plt.show()

# print(contact_sum)
# print(total_points)
# Out:
# 19
# ../data_collection/.insertion0_noise0.4_0004.h5
# ../data_collection/.insertion0_noise0.0_0002.h5
# ../data_collection/.insertion0_noise0.0_0006.h5
# ../data_collection/.insertion0_noise0.4_0001.h5
# ../data_collection/.insertion0_noise0.0_0007.h5
# ../data_collection/.insertion0_noise0.4_0005.h5
# ../data_collection/.insertion0_noise0.0_0003.h5
# ../data_collection/.insertion_noise0_0001.h5
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-925fe1c7a32c> in <module>
#       9     f = loadedit_dataset(filename)
#      10 #     print('insertion' in f.keys())
# ---> 11     hole_type = np.array(f['hole_type'])
#      12     peg_type = np.array(f['peg_type'])
#      13
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# ...

# %%
f= loadedit_dataset("../data_collection/.insertion0_noise0.0_0001.h5")

# %%
for key in f.keys():
    print(key, f[key].shape)
# Out:
# action (1670, 3)
# contact (1670,)
# fit (1,)
# force_hi_freq (1670, 50, 6)
# hole_type (1,)
# joint_pos (1670, 7)
# joint_vel (1670, 7)
# peg_type (1,)
# proprio (1670, 12)

# %%
f.close()

# %%
images = f['depth'][:]

images = images[:, ::-1,...]

plt.imshow(images[100])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-30440486fbde> in <module>
# ----> 1 images = f['depth'][:]
#       2
#       3 images = images[:, ::-1,...]
#       4
#       5 plt.imshow(images[100])
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# ~/miniconda3/envs/guapo/lib/python3.6/site-packages/h5py/_hl/group.py in __getitem__(self, name)
#     260                 raise ValueError("Invalid HDF5 object reference")
#     261         else:
# --> 262             oid = h5o.open(self.id, self._e(name), lapl=self._lapl)
#     263
#     264         otype = h5i.get_type(oid)
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/h5o.pyx in h5py.h5o.open()
#
# ...

# %%
f['depth'].shape
# Out:
# (200, 128, 128)

# %%
for n in range(40,75):
    plt.imshow(np.flipud(f['depth'][n]))
    plt.show()

# %%
min_idx = 0
max_idx = 407
array_1 = np.array(f['proprio'])[min_idx:max_idx]
array_2 = np.array(f['force_hi_freq'])[min_idx:max_idx]
color = ['r', 'g', 'b', 'k', 'purple', 'orange']
for idx, n in enumerate(range(6)):
    plt.plot(range(array_1.shape[0]), array_1[:, n], color = color[idx])
plt.show()
for idx, n in enumerate(range(3)):
    plt.plot(range(array_2.shape[0]), array_2[:,0, n], color = color[idx])
plt.show()
for idx, n in enumerate(range(6,12)):
    plt.plot(range(array_1.shape[0]), array_1[:, n], color = color[idx])
plt.show()

# %%
plt.plot(f['contact'])
# Out:
# 747

# %%
print(np.sum(f['contact'][:]))
# Out:
# 747

# %%
f.close()
